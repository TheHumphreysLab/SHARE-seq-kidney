# %%
import numpy as np
import pandas as pd
import scanpy as sc

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
from matplotlib import rcParams
import matplotlib.font_manager
rcParams['font.sans-serif']=['Arial']
sc.settings.set_figure_params(dpi=100, facecolor='white',fontsize=12)
# Out:
# scanpy==1.7.2 anndata==0.7.6 umap==0.4.6 numpy==1.22.4 scipy==1.6.2 pandas==1.5.2 scikit-learn==0.22 statsmodels==0.12.2 python-igraph==0.9.4

# %%
#adata=sc.read('adata_use.h5ad')

# %%
palette_color=[ '#8DC71E','#69B41E', '#013220',#PT
'#936210', '#5E2A0F',#tL
 '#C9F5E6', '#128394', '#62CCCC', '#046494',#TAL

 '#be658d','#8a3e6a', '#6a3070', '#4c2564',#distal

 '#617A2E', '#A57C00',#ic
]
cell_order=['PT','PT_dediff','PT_VCAM1',  'tL1','tL2',
            'tL-TAL', 'TAL1','TAL2','TAL3', 'DCT', 'CNT', 'PC1','PC2', 'ICA', 'ICB']
plt.rcParams['figure.dpi'] = 300

rcParams['figure.figsize'] =8,3
ax=sns.barplot(data=pd.concat([adata.obs['celltype_2023'], adata.obs['FAO_score2']*1000], axis=1),
            x='celltype_2023',y='FAO_score2',order=cell_order, palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='FAO Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

rcParams['figure.figsize'] =8,3
ax=sns.barplot(data=pd.concat([adata.obs['celltype_2023'], adata.obs['gluconeogenesis_score2']*1000], axis=1),
            x='celltype_2023',y='gluconeogenesis_score2',order=cell_order,palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='Gluconeogenesis Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

rcParams['figure.figsize'] =8,3
ax=sns.barplot(data=pd.concat([adata.obs['celltype_2023'], adata.obs['OXPHOS_score2']*1000], axis=1),
            x='celltype_2023',y='OXPHOS_score2',order=cell_order,palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='OXPHOS Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

rcParams['figure.figsize'] =8,3
ax=sns.barplot(data=pd.concat([adata.obs['celltype_2023'], adata.obs['glycolysis_score']*500], axis=1),
            x='celltype_2023',y='glycolysis_score',order=cell_order,palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='Glycolysis Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

rcParams['figure.figsize'] =8,3
ax=sns.barplot(data=pd.concat([adata.obs['celltype_2023'], adata.obs['glutamine_score2']*1000], axis=1),
            x='celltype_2023',y='glutamine_score2',order=cell_order,palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='Glutamine Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
palette_color=adata.uns['renal_region_new_colors']
cell_order=['C','M','P']

plt.rcParams['figure.dpi'] = 300
rcParams['figure.figsize'] =3,4

ax=sns.barplot(data=pd.concat([adata.obs['renal_region_new'], adata.obs['FAO_score2']*1000], axis=1),
            x='renal_region_new',y='FAO_score2',order=cell_order, palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='FAO Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


ax=sns.barplot(data=pd.concat([adata.obs['renal_region_new'], adata.obs['gluconeogenesis_score2']*1000], axis=1),
            x='renal_region_new',y='gluconeogenesis_score2',order=cell_order,palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='Gluconeogenesis Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


ax=sns.barplot(data=pd.concat([adata.obs['renal_region_new'], adata.obs['OXPHOS_score2']*1000], axis=1),
            x='renal_region_new',y='OXPHOS_score2',order=cell_order,palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='OXPHOS Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


ax=sns.barplot(data=pd.concat([adata.obs['renal_region_new'], adata.obs['glycolysis_score']*500], axis=1),
            x='renal_region_new',y='glycolysis_score',order=cell_order,palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='Glycolysis Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


ax=sns.barplot(data=pd.concat([adata.obs['renal_region_new'], adata.obs['glutamine_score2']*1000], axis=1),
            x='renal_region_new',y='glutamine_score2',order=cell_order,palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='Glutamine Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
adata.obs['celltype_2023'].cat.reorder_categories(['JGA', 'POD', 'PEC', 'PT', 'PT_dediff', 'PT_VCAM1', 'tL1','tL2','tL-TAL',
                                                   'TAL1','TAL2', 'TAL3', 'DCT', 'CNT', 'PC1', 'PC2', 'ICA', 'ICB', 
       'Uro1', 'Uro2', 'ENDO', 'SMC1', 'SMC2', 'SMC3',
       'Fib1', 'Fib2', 'Fib3', 'Ma', 'BT'], inplace=True)
# Out:
# <ipython-input-29-1f62eccf21aa>:1: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   adata.obs['celltype_2023'].cat.reorder_categories(['JGA', 'POD', 'PEC', 'PT', 'PT_dediff', 'PT_VCAM1', 'tL1','tL2','tL-TAL',

# %%
sc.pl.matrixplot(adata, ['PAF_score'] ,groupby = 'celltype_2023',standard_scale='var',cmap='Reds',swap_axes=True)
sc.pl.matrixplot(adata, ['PAF_score'] ,groupby = 'renal_region_new',standard_scale='var',cmap='Reds',swap_axes=True)

# %%
gene_list=['MIOX','GK','PLCH1','SPHK2','IPMK','ITPK1','SPHK1','OCRL','SORD','ITPKC','GALK1','COQ3','COQ2','IMPAD1','ITPKA','ITPKB','GPD2','LEP','PLCD1','PLCH2','DEGS2','PLCD3','MTMR2','INPP1','IPPK','MOGAT3','MOGAT2','MOGAT1','INPPL1','CYP3A4','PLD4','MTMR7','MECP2','TKFC','PLCZ1','PLCE1','IP6K2','IP6K1','PCK1','IP6K3','DGAT2','GOT1','SLC34A1','SGPP2','SGPP1','INPP4B','MINPP1','ACER3','CYP27A1','ACER2','PLCB4','ACER1','INPP4A','SYNJ1','GDPD1','ANGPTL3','PLCB2','PLCB3','PLCB1','ISYNA1','GBA','PTAFR','GDPD2','PTEN','GDE1','NUDT3','GDPD3','GDPD4','GDPD5','FGF2','GK2','NUDT4','NUDT11','GK5','INPP5D','NUDT10','SPTLC1','CYP27B1','INPP5A','PPIP5K1','IMPA1','SPTLC2','INPP5B','IMPA2','PPIP5K2','PTPMT1','CYP2R1','INPP5E','INPP5K','PLCG1','INPP5J','PLCG2'
          ]

#https://maayanlab.cloud/Harmonizome/gene_set/polyol+metabolic+process/GO+Biological+Process+Annotations

sc.tl.score_genes(adata, gene_list,
                  score_name='polyol_score', ctrl_size=len(gene_list),n_bins=1000)
# Out:
# computing score 'polyol_score'
# WARNING: genes are not in var_names and ignored: ['IMPAD1', 'LEP', 'MECP2', 'SLC34A1', 'ANGPTL3', 'GBA', 'PTAFR', 'GDPD2', 'GDPD4', 'FGF2', 'GK5']
# /home/users/hli/anaconda3/lib/python3.8/site-packages/scanpy/tools/_score_genes.py:152: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
#     finished: added
#     'polyol_score', score of gene set (adata.obs).
#     77 total control genes are used. (0:00:02)

# %%
palette_color=[ '#8DC71E','#69B41E', '#013220',#PT
'#936210', '#5E2A0F',#tL
 '#C9F5E6', '#128394', '#62CCCC', '#046494',#TAL

 '#be658d','#8a3e6a', '#6a3070', '#4c2564',#distal

 '#617A2E', '#A57C00',#ic
]
cell_order=['PT','PT_dediff','PT_VCAM1',  'tL1','tL2',
            'tL-TAL', 'TAL1','TAL2','TAL3', 'DCT', 'CNT', 'PC1','PC2', 'ICA', 'ICB']
plt.rcParams['figure.dpi'] = 300

rcParams['figure.figsize'] =8,3
ax=sns.barplot(data=pd.concat([adata.obs['celltype_2023'], adata.obs['polyol_score']*1000], axis=1),
            x='celltype_2023',y='polyol_score',order=cell_order, palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='Polyol Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

palette_color=adata.uns['renal_region_new_colors']
cell_order=['C','M','P']

plt.rcParams['figure.dpi'] = 300
rcParams['figure.figsize'] =3,4

ax=sns.barplot(data=pd.concat([adata.obs['renal_region_new'], adata.obs['polyol_score']*1000], axis=1),
            x='renal_region_new',y='polyol_score',order=cell_order, palette=palette_color,
                ci=95, capsize=.2, errwidth=1)
ax.set(xlabel='', ylabel='Polyol Score\n(normalized)')
ax.grid(False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
adata_tec = adata[adata.obs['tec_use'] == 1, :]

# %%
gene_tec=['ACAA1','ACOX1','HADH','SLC27A2',#FAO_score2
         'PC','ALDOB','PCK1','PCK2',#gluconeogenesis_score2
                    'PHGDH','CTPS1','PPAT','GLS2',#glutamine catalysis
          'PFKFB3','GAPDHS','ALDOC','ENO2',#glycolysis-CoD
          'MGLL','LDHA','IDH2',#carboxylic acid metabolic process
         'COX10','CYC1','UQCRB','SDHB',#OXPHOS_score2
          'SULT1A1','SLC19A3','CSGALNACT1',#sulfur compound metabolic process
          'ALDOA','PFKP','PGK1','PKM',#glycolysis-PC
          'INPP4A','PLCG2','SPTLC2',#polyol metabolism

         ]

sc.settings.set_figure_params(dpi=300, facecolor='white',fontsize=12)
sc.pl.matrixplot(adata_tec, gene_tec, groupby = 'celltype_2023',standard_scale='var',cmap='Reds',
                colorbar_title='Relative\ngene expression')

# %%
adata_atac=sc.read('401875cells_activity_norm.h5ad')
adata_atac
# Out:
# AnnData object with n_obs × n_vars = 401875 × 19957
#     obs: 'orig.ident', 'nCount_peaks', 'nFeature_peaks', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'high.tss', 'nucleosome_group', 'fragments', 'reads_count', 'mononucleosomal', 'nucleosome_free', 'FRiP', 'blacklist_fraction', 'sample_id', 'sample_id_new', 'patient_id', 'batch', 'atac_prep_date', 'renal_region', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'R1_id', 'rna_barcode', 'doublet_score', 'nCount_RNA', 'nFeature_RNA', 'celltype_atac5', 'celltype_atac6', 'renal_region_new2', 'celltype_2023'
#     var: 'features', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std'
# ...

# %%
tec_use=[]
tec_list=[ 'CNT', 'tL1', 'tL2',  'DCT', 'tL-TAL', 'IC', 'PC1', 'PC2', 'PT', 'PT_VCAM1', 'TAL1', 'TAL2/3']
for i in adata_atac.obs['celltype_2023']:
    if i in tec_list:
        tec_use.append(1)
    else:
        tec_use.append(0)
adata_atac.obs['tec_use']=tec_use

# %%
adata_atac_tec = adata_atac[adata_atac.obs['tec_use'] == 1, :]
adata_atac_tec
# Out:
# View of AnnData object with n_obs × n_vars = 339275 × 19957
#     obs: 'orig.ident', 'nCount_peaks', 'nFeature_peaks', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'high.tss', 'nucleosome_group', 'fragments', 'reads_count', 'mononucleosomal', 'nucleosome_free', 'FRiP', 'blacklist_fraction', 'sample_id', 'sample_id_new', 'patient_id', 'batch', 'atac_prep_date', 'renal_region', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'R1_id', 'rna_barcode', 'doublet_score', 'nCount_RNA', 'nFeature_RNA', 'celltype_atac5', 'celltype_atac6', 'renal_region_new2', 'celltype_2023', 'tec_use'
#     var: 'features', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std'
# ...

# %%
sc.pl.matrixplot(adata_atac_tec, gene_tec ,groupby = 'celltype_2023',standard_scale='var',cmap='Greens',use_raw=False,
                colorbar_title='Relative\ngene activity')
